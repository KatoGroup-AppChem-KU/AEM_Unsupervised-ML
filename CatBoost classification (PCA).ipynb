# %%
import sys
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

from pycaret.classification import *
pycaret.__version__

PCA_database_classification = pd.read_csv(r'PCA_database_classification.csv')
mordred_descriptor = PCA_database_classification.loc[:, 'principal component 0_A':]

polymer_info = PCA_database_classification.loc[:, ["Cluster No.","Block A (x)", "Block B (1-x)", "Block A/B ratio","Polymer type"]]

database_classification = pd.concat([polymer_info, mordred_descriptor], axis = 1)
print(database_classification.dtypes)
# Out:
# Cluster No.                   int64
# Block A (x)                 float64
# Block B (1-x)               float64
# Block A/B ratio             float64
# Polymer type                  int64
# principal component 0_A     float64
# principal component 1_A     float64
# principal component 2_A     float64
# principal component 3_A     float64
# principal component 4_A     float64
# principal component 5_A     float64
# principal component 6_A     float64
# principal component 7_A     float64
# principal component 8_A     float64
# principal component 9_A     float64
# principal component 10_A    float64
# principal component 11_A    float64
# principal component 12_A    float64
# principal component 13_A    float64
# principal component 14_A    float64
# principal component 15_A    float64
# principal component 16_A    float64
# principal component 17_A    float64
# principal component 18_A    float64
# principal component 19_A    float64
# principal component 20_A    float64
# principal component 21_A    float64
# principal component 22_A    float64
# principal component 23_A    float64
# principal component 24_A    float64
# principal component 25_A    float64
# principal component 26_A    float64
# principal component 27_A    float64
# principal component 28_A    float64
# principal component 29_A    float64
# principal component 30_A    float64
# principal component 31_A    float64
# principal component 0_B     float64
# principal component 1_B     float64
# principal component 2_B     float64
# principal component 3_B     float64
# principal component 4_B     float64
# principal component 5_B     float64
# principal component 6_B     float64
# principal component 7_B     float64
# principal component 8_B     float64
# principal component 9_B     float64
# principal component 10_B    float64
# principal component 11_B    float64
# principal component 12_B    float64
# principal component 13_B    float64
# principal component 14_B    float64
# principal component 15_B    float64
# principal component 16_B    float64
# principal component 17_B    float64
# principal component 18_B    float64
# principal component 19_B    float64
# principal component 20_B    float64
# principal component 21_B    float64
# principal component 22_B    float64
# principal component 23_B    float64
# principal component 24_B    float64
# principal component 25_B    float64
# principal component 26_B    float64
# principal component 27_B    float64
# principal component 28_B    float64
# principal component 29_B    float64
# principal component 30_B    float64
# principal component 31_B    float64
# dtype: object

# %%
exp_classification = setup(data = database_classification, target = 'Cluster No.', silent = True, session_id = 6989, transformation = False, feature_selection = False, remove_multicollinearity = True, remove_perfect_collinearity = True, normalize=False, ignore_low_variance=False, use_gpu=True)
# Out:
# <style type="text/css">
# #T_6dfa6_row18_col1, #T_6dfa6_row42_col1, #T_6dfa6_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6dfa6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dfa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dfa6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_6dfa6_row0_col1" class="data row0 col1" >6989</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6dfa6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6dfa6_row1_col1" class="data row1 col1" >Cluster No.</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6dfa6_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_6dfa6_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6dfa6_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_6dfa6_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6dfa6_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_6dfa6_row4_col1" class="data row4 col1" >(227, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6dfa6_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_6dfa6_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6dfa6_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_6dfa6_row6_col1" class="data row6 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6dfa6_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_6dfa6_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6dfa6_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_6dfa6_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6dfa6_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_6dfa6_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6dfa6_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_6dfa6_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6dfa6_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_6dfa6_row11_col1" class="data row11 col1" >(158, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6dfa6_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_6dfa6_row12_col1" class="data row12 col1" >(69, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6dfa6_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_6dfa6_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6dfa6_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_6dfa6_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6dfa6_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_6dfa6_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6dfa6_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_6dfa6_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6dfa6_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_6dfa6_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6dfa6_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_6dfa6_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6dfa6_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_6dfa6_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6dfa6_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_6dfa6_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6dfa6_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_6dfa6_row21_col1" class="data row21 col1" >7cda</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_6dfa6_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_6dfa6_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_6dfa6_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_6dfa6_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_6dfa6_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_6dfa6_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_6dfa6_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_6dfa6_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_6dfa6_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_6dfa6_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_6dfa6_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_6dfa6_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_6dfa6_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_6dfa6_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_6dfa6_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_6dfa6_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6dfa6_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_6dfa6_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_6dfa6_row30_col1" class="d

# %%
cat = create_model('catboost')
# Out:
# <style type="text/css">
# #T_bf215_row10_col0, #T_bf215_row10_col1, #T_bf215_row10_col2, #T_bf215_row10_col3, #T_bf215_row10_col4, #T_bf215_row10_col5, #T_bf215_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bf215_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf215_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf215_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_bf215_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_bf215_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_bf215_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_bf215_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_bf215_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_bf215_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf215_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_bf215_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_bf215_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_bf215_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_bf215_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_bf215_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_bf215_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf215_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_bf215_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_bf215_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_bf215_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_bf215_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_bf215_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_bf215_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf215_row3_col0" class="data row3 col0" >0.9375</td>
#       <td id="T_bf215_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_bf215_row3_col2" class="data row3 col2" >0.9524</td>
#       <td id="T_bf215_row3_col3" class="data row3 col3" >0.9583</td>
#       <td id="T_bf215_row3_col4" class="data row3 col4" >0.9375</td>
#       <td id="T_bf215_row3_col5" class="data row3 col5" >0.9263</td>
#       <td id="T_bf215_row3_col6" class="data row3 col6" >0.9306</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf215_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_bf215_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_bf215_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_bf215_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_bf215_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_bf215_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_bf215_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf215_row5_col0" class="data row5 col0" >0.9375</td>
#       <td id="T_bf215_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_bf215_row5_col2" class="data row5 col2" >0.9524</td>
#       <td id="T_bf215_row5_col3" class="data row5 col3" >0.9583</td>
#       <td id="T_bf215_row5_col4" class="data row5 col4" >0.9375</td>
#       <td id="T_bf215_row5_col5" class="data row5 col5" >0.9263</td>
#       <td id="T_bf215_row5_col6" class="data row5 col6" >0.9306</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bf215_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_bf215_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_bf215_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_bf215_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_bf215_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_bf215_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_bf215_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bf215_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_bf215_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_bf215_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_bf215_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_bf215_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_bf215_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_bf215_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bf215_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_bf215_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_bf215_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_bf215_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_bf215_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_bf215_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_bf215_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bf215_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_bf215_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_bf215_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_bf215_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_bf215_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_bf215_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_bf215_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_bf215_row10_col0" class="data row10 col0" >0.9875</td>
#       <td id="T_bf215_row10_col1" class="data row10 col1" >0.2000</td>
#       <td id="T_bf215_row10_col2" class="data row10 col2" >0.9905</td>
#       <td id="T_bf215_row10_col3" class="data row10 col3" >0.9917</td>
#       <td id="T_bf215_row10_col4" class="data row10 col4" >0.9875</td>
#       <td id="T_bf215_row10_col5" class="data row10 col5" >0.9853</td>
#       <td id="T_bf215_row10_col6" class="data row10 col6" >0.9861</td>
#     </tr>
#     <tr>
#       <th id="T_bf215_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_bf215_row11_col0" class="data row11 col0" >0.0250</td>
#       <td id="T_bf215_row11_col1" class="data row11 col1" >0.4000</td>
#       <td id="T_bf215_row11_col2" class="data row11 col2" >0.0190</td>
#       <td id="T_bf215_row11_col3" class="data row11 col3" >0.0167</td>
#       <td id="T_bf215_row11_col4" class="data row11 col4" >0.0250</td>
#       <td id="T_bf215_row11_col5" class="data row11 col5" >0.0295</td>
#       <td id="T_bf215_row11_col6" class="data row11 col6" >0.0278</td>
#     </tr>
#   </tbody>
# </table>

# %%
interpret_model(cat)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# C extension was not built during install!
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
